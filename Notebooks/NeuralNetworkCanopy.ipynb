# %% [markdown]
# <a href="https://colab.research.google.com/github/TheBull8/MachineLearning/blob/main/Notebooks/NeuralNetworkCanopy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Using Canopy Radius, we first determine the DBH as a test. We will then add additional features: age, species, and Lat/Lon.
# Tensorflow and Keras libraries.

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import pandas as pd
from datetime import datetime
from datetime import datetime, timedelta

#Select either YellowN or OrangeN csv file
df = pd.read_csv('YellowN.csv')

# %%
#Age Column computing
def convert_to_date(date_string):
    return datetime.strptime(date_string, '%b-%y').date()

df['DP2'] = df['datePlanted'].apply(convert_to_date)
D1 = datetime.now() - timedelta(days=200)
df['Age'] = (D1 - pd.to_datetime( df['datePlanted'].apply(convert_to_date))).dt.days
df.head()
# Out:
#    Unnamed: 0                                           location          lat  \
# 0         NaN  89 Moo 15 Tumtaopattana village Klangdong sub-...  1.46917E+16
# 1         NaN  89 Moo 15 Tumtaopattana village Klangdong sub-...  1.46914E+16
# 2         NaN  89 Moo 15 Tumtaopattana village Klangdong sub-...  1.46918E+16
# 3         NaN  89 Moo 15 Tumtaopattana village Klangdong sub-...  1.46912E+16
# 4         NaN  89 Moo 15 Tumtaopattana village Klangdong sub-...  1.46914E+16
#
#            lon   id           species datePlanted  height   DBH  canopy  \
# 0  1.01243E+17  432  Mangifera indica      Aug-21     0.5  0.02    0.02
# 1  1.01244E+17  381  Mangifera indica      Aug-21     0.6  0.03    0.18
# 2  1.01243E+17  448  Mangifera indica      Aug-21     0.6  0.02    0.10
# 3  1.01243E+16  356  Mangifera indica      Aug-21     0.7  0.03    0.17
# 4  1.01244E+17  380  Mangifera indica      Aug-21     0.7  0.03    0.20
#
#    canopy area [m^2]         DP2  Age
# 0                NaN  2021-08-01  573
# 1                NaN  2021-08-01  573
# 2                NaN  2021-08-01  573
# 3                NaN  2021-08-01  573
# 4                NaN  2021-08-01  573

# %%
x = df[['canopy']].to_numpy().reshape((-1, 1))
y = np.array(df['DBH'].to_numpy())

# %%
#This is the neural Network training part
import tensorflow as tf
from tensorflow import keras

# Generate some sample data
# Here, we have one input feature (X) and one output (y).


# Define a simple neural network model
model = keras.Sequential([
    keras.layers.Dense(units=1, input_shape=[1])  # One input feature, one output unit
])

# Compile the model
model.compile(optimizer='sgd', loss='mean_squared_error', metrics=['accuracy'])

# Train the model
model.fit(x, y, epochs=100)  # You can adjust the number of epochs as needed

# Make predictions
predictions = model.predict([0.02, 0.03])  # Predict the output for new inputs

print(predictions)
# Out:
# Epoch 1/100
# 11/11 [==============================] - 1s 5ms/step - loss: 2.4269 - accuracy: 0.0000e+00
# Epoch 2/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.3043 - accuracy: 0.0000e+00
# Epoch 3/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.7692 - accuracy: 0.0000e+00
# Epoch 4/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5036 - accuracy: 0.0000e+00
# Epoch 5/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.3725 - accuracy: 0.0000e+00
# Epoch 6/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.3051 - accuracy: 0.0000e+00
# Epoch 7/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2664 - accuracy: 0.0000e+00
# Epoch 8/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.2438 - accuracy: 0.0000e+00
# Epoch 9/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2284 - accuracy: 0.0000e+00
# Epoch 10/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2162 - accuracy: 0.0000e+00
# Epoch 11/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2062 - accuracy: 0.0000e+00
# Epoch 12/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.1976 - accuracy: 0.0000e+00
# Epoch 13/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.1893 - accuracy: 0.0000e+00
# Epoch 14/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.1817 - accuracy: 0.0000e+00
# Epoch 15/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1744 - accuracy: 0.0000e+00
# Epoch 16/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.1676 - accuracy: 0.0000e+00
# Epoch 17/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1610 - accuracy: 0.0000e+00
# Epoch 18/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1547 - accuracy: 0.0000e+00
# Epoch 19/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1488 - accuracy: 0.0000e+00
# Epoch 20/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1432 - accuracy: 0.0000e+00
# Epoch 21/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1377 - accuracy: 0.0000e+00
# Epoch 22/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1325 - accuracy: 0.0000e+00
# Epoch 23/100
# 11/11 [==============================] - 0s 2ms/step - loss: 0.1276 - accuracy: 0.0000e+00
# Epoch 24/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.1230 - accuracy: 0.0000e+00
# Epoch 25/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1186 - accuracy: 0.0000e+00
# Epoch 26/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1142 - accuracy: 0.0000e+00
# Epoch 27/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1102 - accuracy: 0.0000e+00
# Epoch 28/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1063 - accuracy: 0.0000e+00
# Epoch 29/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.1026 - accuracy: 0.0000e+00
# Epoch 30/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0991 - accuracy: 0.0000e+00
# Epoch 31/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0957 - accuracy: 0.0000e+00
# Epoch 32/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0925 - accuracy: 0.0000e+00
# Epoch 33/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0895 - accuracy: 0.0000e+00
# Epoch 34/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0866 - accuracy: 0.0000e+00
# Epoch 35/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0838 - accuracy: 0.0000e+00
# Epoch 36/100
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0812 - accuracy: 0.0000e+00
# Epoch 37/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0786 - accuracy: 0.0000e+00
# Epoch 38/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0762 - accuracy: 0.0000e+00
# Epoch 39/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0738 - accuracy: 0.0000e+00
# Epoch 40/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0716 - accuracy: 0.0000e+00
# Epoch 41/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0695 - accuracy: 0.0000e+00
# Epoch 42/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0675 - accuracy: 0.0000e+00
# Epoch 43/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0656 - accuracy: 0.0000e+00
# Epoch 44/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0638 - accuracy: 0.0000e+00
# Epoch 45/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0621 - accuracy: 0.0000e+00
# Epoch 46/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0604 - accuracy: 0.0000e+00
# Epoch 47/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0588 - accuracy: 0.0000e+00
# Epoch 48/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0572 - accuracy: 0.0029
# Epoch 49/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0558 - accuracy: 0.0029
# Epoch 50/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0545 - accuracy: 0.0029
# Epoch 51/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0531 - accuracy: 0.0029
# Epoch 52/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0519 - accuracy: 0.0029
# Epoch 53/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0507 - accuracy: 0.0029
# Epoch 54/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0496 - accuracy: 0.0029
# Epoch 55/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0485 - accuracy: 0.0058
# Epoch 56/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0474 - accuracy: 0.0058
# Epoch 57/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0464 - accuracy: 0.0058
# Epoch 58/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0455 - accuracy: 0.0058
# Epoch 59/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0446 - accuracy: 0.0058
# Epoch 60/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0437 - accuracy: 0.0058
# Epoch 61/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0430 - accuracy: 0.0058
# Epoch 62/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0422 - accuracy: 0.0058
# Epoch 63/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0415 - accuracy: 0.0058
# Epoch 64/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0407 - accuracy: 0.0058
# Epoch 65/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0400 - accuracy: 0.0058
# Epoch 66/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0394 - accuracy: 0.0058
# Epoch 67/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0388 - accuracy: 0.0058
# Epoch 68/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0382 - accuracy: 0.0058
# Epoch 69/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0376 - accuracy: 0.0058
# Epoch 70/100
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0370 - accuracy: 0.0058
# Epoch 71/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0366 - accuracy: 0.0058
# Epoch 72/100
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0361 - accuracy: 0.0058
# Epoch 73/100
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0356 - accuracy: 0.0058
# Epoch 74/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0352 - accuracy: 0.0058
# Epoch 75/100
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0347 - accuracy: 0.0058
# Epoch 76/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0344 - accuracy: 0.0058
# Epoch 77/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0340 - accuracy: 0.0058
# Epoch 78/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0336 - accuracy: 0.0058
# Epoch 79/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0332 - accuracy: 0.0058
# Epoch 80/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0329 - accuracy: 0.0058
# Epoch 81/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0326 - accuracy: 0.0058
# Epoch 82/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0323 - accuracy: 0.0058
# Epoch 83/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0320 - accuracy: 0.0058
# Epoch 84/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0317 - accuracy: 0.0058
# Epoch 85/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0315 - accuracy: 0.0058
# Epoch 86/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0312 - accuracy: 0.0058
# Epoch 87/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0309 - accuracy: 0.0058
# Epoch 88/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0307 - accuracy: 0.0058
# Epoch 89/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0305 - accuracy: 0.0058
# Epoch 90/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0303 - accuracy: 0.0058
# Epoch 91/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0301 - accuracy: 0.0058
# Epoch 92/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0299 - accuracy: 0.0058
# Epoch 93/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0297 - accuracy: 0.0058
# Epoch 94/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0295 - accuracy: 0.0058
# Epoch 95/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0294 - accuracy: 0.0058
# Epoch 96/100
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0292 - accuracy: 0.0058
# Epoch 97/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0291 - accuracy: 0.0058
# Epoch 98/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0289 - accuracy: 0.0058
# Epoch 99/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0288 - accuracy: 0.0058
# Epoch 100/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0287 - accuracy: 0.0058
# 1/1 [==============================] - 0s 227ms/step
# [[0.02987579]
#  [0.03436266]]
