# %% [markdown]
# <a href="https://colab.research.google.com/github/TheBull8/MachineLearning/blob/main/notebooks/Raster.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install rasterio
# !pip install geopandas

# %%
# !pip install pandas

# %%
import geopandas as gpd
import rasterio as rio

# %%
x = gpd.read_file("gis_osm_places_07_1.shp")

x["temp"] = 0

for index, row in x.iterrows():
  print(row)
# Out:
# geometry    POINT (1.4442469 43.6044622)
# temp                                   0
# Name: 0, dtype: object
# geometry    POINT (1.3466543 43.5827846)
# temp                                   0
# Name: 1, dtype: object
# geometry    POINT (1.3457537 43.5369936)
# temp                                   0
# Name: 2, dtype: object
# geometry    POINT (1.37799 43.6434)
# temp                              0
# Name: 3, dtype: object
# geometry    POINT (1.2978343 43.5653012)
# temp                                   0
# Name: 4, dtype: object
# geometry    POINT (1.3282149 43.6121001)
# temp                                   0
# Name: 5, dtype: object
# geometry    POINT (1.4846885 43.6501518)
# temp                                   0
# Name: 6, dtype: object
# geometry    POINT (1.5620588 43.5183908)
# temp                                   0
# Name: 7, dtype: object
# geometry    POINT (1.4291655 43.6687865)
# temp                                   0
# Name: 8, dtype: object
# ...
